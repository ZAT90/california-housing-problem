# %%
# Import Libraries
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Function to load the data
def load_data():
    california = fetch_california_housing()
    X = pd.DataFrame(california.data, columns=california.feature_names)
    y = pd.Series(california.target)
    return X, y

# Function to split the data
def split_data(X, y, test_size=0.2, random_state=42):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    return X_train, X_test, y_train, y_test

# Function to scale the data
def scale_data(X_train, X_test):
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    return X_train_scaled, X_test_scaled

# Function to build the neural network model
def build_model(input_shape):
    model = Sequential([
        Dense(64, activation='relu', input_shape=(input_shape,)),
        Dense(32, activation='relu'),
        Dense(1, activation='linear')  # Linear activation for regression
    ])
    model.compile(optimizer='adam', loss='mse')
    return model

# Function to train the model
def train_model(model, X_train, y_train, validation_split=0.2, epochs=100, batch_size=32):
    history = model.fit(X_train, y_train, validation_split=validation_split, epochs=epochs, batch_size=batch_size, verbose=1)
    return history

# Function to evaluate the model
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    print(f"Mean Squared Error: {mse}")
    return mse


# 1. Load data
X, y = load_data()

# 2. Split the data
X_train, X_test, y_train, y_test = split_data(X, y)

# 3. Scale the data
X_train_scaled, X_test_scaled = scale_data(X_train, X_test)

# 4. Build the model
model = build_model(X_train_scaled.shape[1])

# 5. Train the model
train_model(model, X_train_scaled, y_train)

# 6. Evaluate the model
evaluate_model(model, X_test_scaled, y_test)
# Out:
# 2024-11-11 22:21:46.745554: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# /usr/local/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.9566 - val_loss: 0.4952
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.4318 - val_loss: 0.4215
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.3706 - val_loss: 0.4276
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5265 - val_loss: 0.3872
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3412 - val_loss: 0.3726
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 0.3318 - val_loss: 0.3529
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3278 - val_loss: 0.3593
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.3177 - val_loss: 0.3432
# Epoch 9/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3367 - val_loss: 0.3354
# Epoch 10/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 0.3158 - val_loss: 0.3381
# Epoch 11/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 0.2924 - val_loss: 0.3348
# Epoch 12/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3045 - val_loss: 0.3279
# Epoch 13/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 0.3023 - val_loss: 0.3271
# Epoch 14/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 0.2906 - val_loss: 0.3230
# Epoch 15/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3147 - val_loss: 0.3387
# Epoch 16/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.3110 - val_loss: 0.3208
# Epoch 17/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.2966 - val_loss: 0.3254
# Epoch 18/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2798 - val_loss: 0.3156
# Epoch 19/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 0.2833 - val_loss: 0.3129
# Epoch 20/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 0.2794 - val_loss: 0.3103
# Epoch 21/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 0.2831 - val_loss: 0.3118
# Epoch 22/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2810 - val_loss: 0.3067
# Epoch 23/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 0.2792 - val_loss: 0.3035
# Epoch 24/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 0.2683 - val_loss: 0.3041
# Epoch 25/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.2730 - val_loss: 0.3137
# Epoch 26/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2809 - val_loss: 0.3063
# Epoch 27/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2837 - val_loss: 0.3039
# Epoch 28/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2740 - val_loss: 0.3112
# Epoch 29/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.2732 - val_loss: 0.3139
# Epoch 30/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 0.2618 - val_loss: 0.3019
# Epoch 31/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2667 - val_loss: 0.3162
# Epoch 32/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 0.2738 - val_loss: 0.3101
# Epoch 33/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 0.2554 - val_loss: 0.2998
# Epoch 34/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2604 - val_loss: 0.2965
# Epoch 35/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.2656 - val_loss: 0.2975
# Epoch 36/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2610 - val_loss: 0.2947
# Epoch 37/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2551 - val_loss: 0.2998
# Epoch 38/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2542 - val_loss: 0.3035
# Epoch 39/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2641 - val_loss: 0.2905
# Epoch 40/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 0.2582 - val_loss: 0.3046
# Epoch 41/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2602 - val_loss: 0.2916
# Epoch 42/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 0.2638 - val_loss: 0.2962
# Epoch 43/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2596 - val_loss: 0.3056
# Epoch 44/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2663 - val_loss: 0.2898
# Epoch 45/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2484 - val_loss: 0.2996
# Epoch 46/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.2509 - val_loss: 0.2950
# Epoch 47/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2479 - val_loss: 0.2960
# Epoch 48/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 0.2479 - val_loss: 0.2947
# Epoch 49/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2533 - val_loss: 0.2908
# Epoch 50/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 0.2567 - val_loss: 0.2899
# Epoch 51/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 0.2454 - val_loss: 0.2992
# Epoch 52/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.2545 - val_loss: 0.2972
# Epoch 53/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 0.2468 - val_loss: 0.2898
# Epoch 54/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.2461 - val_loss: 0.2924
# Epoch 55/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.2400 - val_loss: 0.2930
# Epoch 56/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 0.2438 - val_loss: 0.2923
# Epoch 57/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.2601 - val_loss: 0.2860
# Epoch 58/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 0.2378 - val_loss: 0.2837
# Epoch 59/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 0.2457 - val_loss: 0.2928
# Epoch 60/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2469 - val_loss: 0.2873
# Epoch 61/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2323 - val_loss: 0.3071
# Epoch 62/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2419 - val_loss: 0.2869
# Epoch 63/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2370 - val_loss: 0.2965
# Epoch 64/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2362 - val_loss: 0.2951
# Epoch 65/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2536 - val_loss: 0.2931
# Epoch 66/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2468 - val_loss: 0.2814
# Epoch 67/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2399 - val_loss: 0.2934
# Epoch 68/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2437 - val_loss: 0.2944
# Epoch 69/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2369 - val_loss: 0.2830
# Epoch 70/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2483 - val_loss: 0.2914
# Epoch 71/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2471 - val_loss: 0.2872
# Epoch 72/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2449 - val_loss: 0.2894
# Epoch 73/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2271 - val_loss: 0.2903
# Epoch 74/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2381 - val_loss: 0.2792
# Epoch 75/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2334 - val_loss: 0.2916
# Epoch 76/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2360 - val_loss: 0.2795
# Epoch 77/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2374 - val_loss: 0.2907
# Epoch 78/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2275 - val_loss: 0.2976
# Epoch 79/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2222 - val_loss: 0.2867
# Epoch 80/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2194 - val_loss: 0.2925
# Epoch 81/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2376 - val_loss: 0.2893
# Epoch 82/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2223 - val_loss: 0.2820
# Epoch 83/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2468 - val_loss: 0.2792
# Epoch 84/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2356 - val_loss: 0.2819
# Epoch 85/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2239 - val_loss: 0.2848
# Epoch 86/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2303 - val_loss: 0.2872
# Epoch 87/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2311 - val_loss: 0.2806
# Epoch 88/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2405 - val_loss: 0.2804
# Epoch 89/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2306 - val_loss: 0.2771
# Epoch 90/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2272 - val_loss: 0.2810
# Epoch 91/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2395 - val_loss: 0.2771
# Epoch 92/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2267 - val_loss: 0.2769
# Epoch 93/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2345 - val_loss: 0.2955
# Epoch 94/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2315 - val_loss: 0.2872
# Epoch 95/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2350 - val_loss: 0.2748
# Epoch 96/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2294 - val_loss: 0.2844
# Epoch 97/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2329 - val_loss: 0.2873
# Epoch 98/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2211 - val_loss: 0.2790
# Epoch 99/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2310 - val_loss: 0.2782
# Epoch 100/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2231 - val_loss: 0.2801
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Mean Squared Error: 0.27992914075299513
# 0.27992914075299513
